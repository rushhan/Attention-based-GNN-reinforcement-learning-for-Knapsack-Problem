# %%
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks/attention-learn-to-route-master/
# Out:
# /content/drive/My Drive/Colab Notebooks/attention-learn-to-route-master

# %%
# !ls
# Out:
# environment.yml   knapsack.ipynb  plot_vrp.ipynb  reinforce_baselines.py  utils
# eval.py		  LICENSE	  pretrained	  run.py
# generate_data.py  nets		  problems	  simple_tsp.ipynb
# images		  options.py	  README.md	  train.py

# %%
pip install tensorboard_logger

# %%
(a[:, :, None, :] - a[:, None, :, :]).shape
# Out:
# torch.Size([3, 4, 4, 2])

# %%
# !ls
# Out:
# environment.yml   knapsack.ipynb  plot_vrp.ipynb  reinforce_baselines.py  utils
# eval.py		  LICENSE	  pretrained	  run.py
# generate_data.py  nets		  problems	  simple_tsp.ipynb
# images		  options.py	  README.md	  train.py

# %%
# !python run.py --graph_size 20 --baseline rollout  --run_name  'knapsack' --problem 'cvrp'
# Out:
# 2020-08-26 15:05:08.687446: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# {'baseline': 'rollout',
#  'batch_size': 512,
#  'bl_alpha': 0.05,
#  'bl_warmup_epochs': 1,
#  'checkpoint_encoder': False,
#  'checkpoint_epochs': 1,
#  'data_distribution': None,
#  'embedding_dim': 128,
#  'epoch_size': 1280000,
#  'epoch_start': 0,
#  'eval_batch_size': 1024,
#  'eval_only': False,
#  'exp_beta': 0.8,
#  'graph_size': 20,
#  'hidden_dim': 128,
#  'load_path': None,
#  'log_dir': 'logs',
#  'log_step': 50,
#  'lr_critic': 0.0001,
#  'lr_decay': 1.0,
#  'lr_model': 0.0001,
#  'max_grad_norm': 1.0,
#  'model': 'attention',
#  'n_encode_layers': 3,
#  'n_epochs': 100,
#  'no_cuda': False,
#  'no_progress_bar': False,
#  'no_tensorboard': False,
#  'normalization': 'batch',
#  'output_dir': 'outputs',
#  'problem': 'cvrp',
#  'resume': None,
#  'run_name': 'knapsack_20200826T150517',
# ...

# %%
import torch
import numpy
a = torch.zeros([1024, 1, 20]).bool()
~a
#b =  torch.rand([1024, 1, 20])
#a[:,:,1:].sum(-1).sum(-1).sum(-1).numpy()
#(torch.mult(a).float()==0.0).item()
#torch.equal(a[:,:,1:].sum(-1).sum(-1).sum(-1),torch.tensor([0.]))
# Out:
# tensor([[[True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True]],
#
#         ...,
#
#         [[True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True]]])
